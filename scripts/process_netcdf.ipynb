# %%
import xarray as xr


path = "/home/dyami/Documents/git/bathymesh/data/raw/mhi_mbsyn_bathytopo_1km_v21.nc"

ds = xr.load_dataset(path)

ds
# Out:
# Jupyter cannot be started. Error attempting to locate Jupyter: 'Kernelspec' module not installed in the selected interpreter (/home/dyami/Documents/git/bathymesh/.venv/bin/python).
#
#  Please re-install or update 'jupyter'.
#
# Install 'jupyter and notebook' into the Python environment.
#
# Command: 'python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U'
#
# Click <a href='https://aka.ms/installJupyterForVSCode'>here</a> for more info.
